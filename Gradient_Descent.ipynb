# %% [markdown]
# #### Gradient Descent
# ##### Gradient descent is a function which minimise the cost Function
# #### Formula of minimizing the cost function is for linear Regression is J=2m1​(f(x)−y)2
#
# 1.
# 𝐽
# J
#
# This is the cost (the error of the model).
# We want to minimize this.
#
# 2.
# 𝑚
# m
#
# The number of training examples.
#
# Example:
# If your dataset has 100 rows →
# 𝑚
# =
# 100
# m=100
#
# 3.
# 𝑓
# (
# 𝑥
# )
# f(x)
#
# This is the prediction made by the model.
#
# In simple linear regression:
#
# 𝑓
# (
# 𝑥
# )
# =
# 𝑚
# 𝑥
# +
# 𝑏
# f(x)=mx+b
#
# 𝑚
# m → slope (parameter 1)
#
# 𝑏
# b → intercept (parameter 2)
#
# These two are the parameters that gradient descent will change.
#
# 4.
# 𝑦
# y
#
# The actual value from the dataset (true output).
#
# 5.
# (
# 𝑓
# (
# 𝑥
# )
# −
# 𝑦
# )
# 2
# (f(x)−y)
# 2
#
# This is the squared error — how wrong the prediction is.
#
# 🔥 Putting it all together — How it works
#
# Let’s explain the whole formula step-by-step:
#
# ⭐ Step 1: Model makes a prediction
#
# For each training example
# 𝑥
# 𝑖
# x
